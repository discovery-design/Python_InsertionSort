# %%
import requests 
from bs4 import BeautifulSoup as bs
import urllib

source = urllib.request.urlopen('https://tcmb.gov.tr/kurlar/today.xml').read()
soup = bs(source,'xml')
currencies=soup.find_all('Currency')

##Kur isimlerini yazdıralım.
##names=soup.find_all('CurrencyName')
##names

# for i in names:
#     print(i)

##Kur değerlerini yazdıralım.
for i in currencies:
    print(i.text)
# Out:
# 1
# ABD DOLARI
# US DOLLAR
# 18.6312
# 18.6647
# 18.6181
# 18.6927
#
#
#
#
# 1
# AVUSTRALYA DOLARI
# AUSTRALIAN DOLLAR
# 12.4791
# 12.5605
# 12.4217
# 12.6358
# 1.4895
#
#
#
# 1
# DANİMARKA KRONU
# DANISH KRONE
# 2.6568
# 2.6698
# 2.6549
# 2.6759
# 7.0019
#
#
#
# 1
# EURO
# EURO
# 19.7925
# 19.8282
# 19.7787
# 19.8579
#
# 1.0623
#
#
# 1
# İNGİLİZ STERLİNİ
# POUND STERLING
# 22.6898
# 22.8081
# 22.6739
# 22.8423
#
# 1.2199
#
#
# 1
# İSVİÇRE FRANGI
# SWISS FRANK
# 19.9692
# 20.0974
# 19.9392
# 20.1275
# 0.9309
#
#
#
# 1
# İSVEÇ KRONU
# SWEDISH KRONA
# 1.7895
# 1.8081
# 1.7883
# 1.8122
# 10.37
#
#
#
# 1
# KANADA DOLARI
# CANADIAN DOLLAR
# 13.6280
# 13.6895
# 13.5776
# 13.7415
# 1.3653
#
#
#
# 1
# KUVEYT DİNARI
# KUWAITI DINAR
# 60.4445
# 61.2355
# 59.5379
# 62.1540
#
# 3.2626
#
#
# 1
# NORVEÇ KRONU
# NORWEGIAN KRONE
# 1.8831
# 1.8957
# 1.8817
# 1.9001
# 9.8698
#
#
#
# 1
# SUUDİ ARABİSTAN RİYALİ
# SAUDI RIYAL
# 4.9530
# 4.9619
# 4.9158
# 4.9991
# 3.7616
#
#
#
# 100
# JAPON YENİ
# ...
